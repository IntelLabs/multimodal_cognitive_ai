# %%
from datasets import load_dataset

# %%
example = load_dataset('Intel/COCO-Counterfactuals', use_auth_token=True)
# Out:
# ...
# Extracting data files #0:   0%|          | 0/1 [00:00<?, ?obj/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset coco-counterfactuals downloaded and prepared to /home/tieple/.cache/huggingface/datasets/Intel___coco-counterfactuals/default/0.0.0/3c54a8be6c749b1b9194a7e22526e631091c2c9359568393cd7b080fda7f4419. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
example
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['id', 'image_0', 'image_1', 'caption_0', 'caption_1'],
#         num_rows: 17410
#     })
# })

# %%
example['test'][8]
# Out:
# {'id': '42296_0',
#  'image_0': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  'image_1': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  'caption_0': 'a polar bear partially submerged in a body of water',
#  'caption_1': 'a polar bear partially submerged in a body of ice'}

# %%
example['test'][8]['image_0']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
example['test'][8]['image_1']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
